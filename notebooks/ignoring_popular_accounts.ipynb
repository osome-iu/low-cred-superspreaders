# %% [markdown]
# ### This notebook will investigate how Twitter deletes accounts

# %%
import sys
sys.path.insert(0, '../src_clean')
from utils import Loader
from utils import convert_twitter_strings_2_dates
import datetime
import numpy as np
import pandas as pd

import os
import json
import matplotlib.pyplot as plt
import seaborn as sns
import altair as alt
from altair_saver import save

from scipy.stats import mannwhitneyu, pearsonr

alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %% [markdown]
# ### Load necessary data

# %%
l = Loader()

decahose_users = l.load_user_data(name = "decahose")

superspreader_accounts = l.load_iffyp_top_infl_fiber_users()

errors = l.load_user_data(name="v2",info_type="errors")
errors["user_id"] = errors["user_id"].astype(str)

# %%
decahose_users
# Out:
#                       u_id  followers_count  following_count  tweet_count  \
# 0      1000003671780884485       251.333333            192.0      2570.00
# 1                100001226       127.000000            232.0      5515.00
# 2               1000051927       415.000000           3606.0       548.00
# 3      1000060610518896640      4096.750000           1080.5      5532.75
# 4      1000075699699486722        32.000000            338.0     16696.50
# ...                    ...              ...              ...          ...
# 47007   999864765177565184       437.000000            813.0     19931.00
# 47008             99988999        70.000000            359.0      7662.00
# 47009   999951635697848320        25.000000             15.0       261.00
# 47010   999962540934221826       111.000000            154.0      8295.00
# 47011   999983032760225792     16259.000000            671.0     12935.00
#
#        listed_count                                       name  protected  \
# 0               0.0                         Enchanted LifePath      False
# 1               1.0                                     ramjee      False
# 2               6.0                            Vishal Tripathi      False
# 3              15.5                            Mattea Merta 🇨🇦      False
# 4               1.0                            Deborah Griffin      False
# ...             ...                                        ...        ...
# 47007           1.0  Christopher Ramírez, 🇵🇷🇺🇸🇪🇸#Conservative⛪      False
# 47008           7.0                       Marc Boucher de Lign      False
# 47009           1.0                                   aramchei      False
# 47010           0.0                               Tantivy Trig      False
# 47011          15.0                             Pooja Singh 🇮🇳      False
#
#                            created_at         username  \
# 0      Fri May 25 09:20:29 -0400 2018  TruthWeRTheNews
# 1      Mon Dec 28 12:24:56 -0500 2009      ramjeepasam
# 2      Sun Dec 09 14:58:56 -0500 2012       vishaltrip
# 3      Fri May 25 13:06:44 -0400 2018      MatteaMerta
# 4      Fri May 25 14:06:42 -0400 2018  Deborah00274412
# ...                               ...              ...
# 47007  Fri May 25 00:08:31 -0400 2018  Christo27341164
# 47008  Mon Dec 28 11:26:52 -0500 2009         MarcBdeL
# 47009  Fri May 25 05:53:42 -0400 2018         aramchei
# 47010  Fri May 25 06:37:02 -0400 2018         TantivyT
# 47011  Fri May 25 07:58:28 -0400 2018   ThePoojaSingh1
#
#                                              description  verified  \
# 0      Enchanted LifePath TV - Search For Answers Fin...     False
# 1                                                   None     False
# 2      Young Professional @NITIAayog | Lawyer by qual...     False
# 3      Free Thinker | Contributor @TPostMillennial | ...     False
# 4      Single,never married, Southern belle over 59 u...     False
# ...                                                  ...       ...
# 47007  I love italy🇮🇹Denmark🇩🇰,Croatia🇭🇷,Greece🇬🇷Spai...     False
# 47008  concepteur et co-fondateur de HolaVie. Narurop...     False
# 47009                                               None     False
# 47010  Unwavering commitment to saving lives.\n\nTrut...     False
# 47011                                     No Twitter bio     False
#
#                                          url
# 0               http://EnchantedLifePath.com
# 1                                       None
# 2                                       None
# 3      https://www.facebook.com/MatteaMerta/
# 4                                       None
# ...                                      ...
# 47007                                   None
# 47008                 http://www.holavie.org
# 47009                                   None
# 47010                                   None
# 47011                       http://becil.com
#
# [47012 rows x 12 columns]

# %%
superspreader_accounts
# Out:
# ['275276082',
#  '49023129',
#  '2451476942',
#  '3507100335',
#  '16936686',
#  '16589206',
#  '940430173517811714',
#  '57431771',
#  '878916812',
#  '39344374',
#  '16989178',
#  '49682880',
#  '1177221975921610753',
#  '22677397',
#  '941729680381550592',
#  '850036892',
#  '3220084809',
#  '25251653',
#  '1036239330984054784',
#  '1909921760',
#  '101779040',
#  '1146225861743403008',
#  '3394053112',
#  '19553409',
#  '19422491',
#  '1229160464',
#  '58691526',
#  '997312910748680192',
#  '727137760574857216',
#  '115279420',
#  '1216789842',
#  '19329393',
#  '95588504',
#  '375721095',
#  '1134691864425033730',
#  '2176476241',
#  '806168918754660352',
#  '1398479138',
#  '802121664',
#  '822901284655210497',
#  '21150492',
#  '4789453135',
#  '39743812',
#  '1424605753',
#  '1157673159128207361',
#  '3155188814',
#  '898577623885819904',
#  '3041775900',
#  '959856286061006848',
#  '56491860',
#  '138889809',
#  '903313767596822528',
#  '770781940341288960',
#  '22240612',
#  '435704007',
#  '975217231',
#  '769739202963517440',
#  '86177206',
#  '859592034',
#  '1148711615686160384',
#  '899115298997055491',
#  '782018153207431168',
#  '3192962633',
#  '348113898',
#  '1225779630',
#  '1494835716',
#  '14247236',
#  '50434327',
#  '897210765949648896',
#  '413513361',
#  '27493883',
#  '40899671',
#  '46934022',
#  '2248093283',
#  '923368757803847680',
#  '15416505',
#  '856991644134068224',
#  '125128723',
#  '2315583427',
#  '864934909961523200',
#  '1088817055602757633',
#  '1037648264672079872',
#  '29398579',
#  '78523300',
#  '1168793817148821504',
#  '41160276',
#  '18247062',
#  '17980523',
#  '11454572',
#  '2946730163',
#  '920006546829975553',
#  '446228264',
#  '2413821780',
#  '741419766867337216',
#  '83932539',
#  '477174486',
#  '1176477972515213312',
#  '24787367',
#  '43753976',
#  '16279880',
#  '913416571548205057',
#  '1217456391251808256',
#  '800086706678419456',
#  '29873671',
#  '829717519',
#  '806347865073315844',
#  '1478430702',
#  '272064857',
#  '1886468286',
#  '186562905',
#  '870468896255385601',
#  '1904739704',
#  '3530404094',
#  '266237495',
#  '19130146',
#  '22956220',
#  '9427572',
#  '1697365488',
#  '1096854816423170048',
#  '1546656000',
#  '71869296',
#  '92928883',
#  '1134618385495527425',
#  '298633547',
#  '875017115979403264',
#  '1121554471',
#  '2369910918',
#  '966716807452258304',
#  '1106312355267469312',
#  '1134666552718925824',
#  '562255311',
#  '711267839',
#  '478855762',
#  '310965182',
#  '341194704',
#  '41634520',
#  '234497162',
#  '187022370',
#  '917501529480765441',
#  '811308998108573696',
#  '2417586104',
#  '1196926455990632449',
#  '4665676362',
#  '17537467',
#  '861186587144577025',
#  '232901331',
#  '725064846056640512',
#  '2757833205',
#  '1392956425',
#  '752214001',
#  '1071493866489044993',
#  '462104542',
#  '2713937910',
#  '94120026',
#  '921880207870459904',
#  '4798259061',
#  '3283495219',
#  '23360808',
#  '3775360879',
#  '1026684533364547594',
#  '3353061012',
#  '1344897174',
#  '1906242157',
#  '1162682346094522370',
#  '3369234799',
#  '1043185714437992449',
#  '403647191',
#  '52544275',
#  '1000141948269678592',
#  '73928096',
#  '1049162319941517312',
#  '592730371',
#  '769108935726997504',
#  '1118205222726307842',
#  '162301746',
#  '764261361044037632',
#  '586707638',
#  '2433154158',
#  '2333707213',
#  '815552224046829568',
#  '1018425398869282817',
#  '1162759864939999237',
#  '123617604',
#  '424664120',
#  '499230066',
#  '43035019',
#  '969444209940889600',
#  '2981776113',
#  '965259182',
#  '83182871',
#  '635928417',
#  '347586568',
#  '2923411356',
#  '38495835',
#  '734168909553766405',
#  '594886554',
#  '1219007111239282688',
#  '1199522589573554176',
#  '822510151642923009',
#  '1199631548095619072',
#  '1674315427',
#  '2748355923',
#  '69557688',
#  '11134252',
#  '1340481373',
#  '18837791',
#  '4765364386',
#  '1134783407223975937',
#  '43596406',
#  '116356889',
#  '826339456223498240',
#  '23023227',
#  '1191935744220246016',
#  '126911579',
#  '2924521080',
#  '26487169',
#  '915231714724712448',
#  '3314383418',
#  '2950103415',
#  '1153042794375712770',
#  '2725865306',
#  '16740433',
#  '187936720',
#  '561310591',
#  '14377605',
#  '18643437',
#  '414223436',
#  '27522964',
#  '2256965582',
#  '804435407400095745',
#  '803017539903029248',
#  '1194770389634895873',
#  '244351421',
#  '1023362107',
#  '18266688',
#  '1010682068131557376',
#  '26028938',
#  '16269666',
#  '47957425',
#  '406483952',
#  '2795404498',
#  '4918885219',
#  '85498982',
#  '16585101',
#  '1274690550',
#  '954124423',
#  '839099917121511425',
#  '631310817',
#  '895286614431346688',
#  '1215417589414821889']

# %%
errors.head()
# Out:
#                user_id                        status  \
# 0  1204429316219691008       User has been suspended
# 1  1229861495326093312       User has been suspended
# 2  1211401123275296770  Could not find user with ids
# 3           2994893355       User has been suspended
# 4  1083180973276229632       User has been suspended
#
#                                        twitter_error
# 0  https://api.twitter.com/2/problems/resource-no...
# 1  https://api.twitter.com/2/problems/resource-no...
# 2  https://api.twitter.com/2/problems/resource-no...
# 3  https://api.twitter.com/2/problems/resource-no...
# 4  https://api.twitter.com/2/problems/resource-no...

# %% [markdown]
# ### Append the user account data to the top FIBers and Influentials

# %%
ss_account_info = decahose_users[decahose_users['u_id'].isin(superspreader_accounts)].reset_index(drop=True)

# %%
ss_account_info = ss_account_info[
    ["u_id",
     "followers_count",
     "following_count",
     "tweet_count",
     "username",
     "description",
     "verified",
     "protected"]
]
ss_account_info
# Out:
#                     u_id  followers_count  following_count    tweet_count  \
# 0    1000141948269678592     56366.039735     56903.993377   96973.688742
# 1    1010682068131557376     13237.791667     13281.125000   65105.958333
# 2              101779040     85459.535714       199.464286  136737.321429
# 3    1018425398869282817     10784.678218        25.217822    7084.831683
# 4             1023362107     31915.972868       358.982558    7770.236434
# ..                   ...              ...              ...            ...
# 245            965259182     54812.569182     37505.399371  467860.204403
# 246   966716807452258304     34011.982222     34308.720000   42249.004444
# 247   969444209940889600     42852.500000     28818.166667  181323.166667
# 248            975217231    152649.985294     98170.279412  323830.455882
# 249   997312910748680192     42967.622807     43533.035088  175056.368421
#
#             username                                        description  \
# 0     209acesheepdog  🇺🇸🐶1A🗞~2A🔫CHRISTIAN⛪ CONSERVATIVE 💪\nMAR.30yrs...
# 1          DebHaslam  WWG1WGA👮‍♂️#MAGA🇺🇸❤️#TRUMP2020❤️🇺🇸 MY PAGE IS ...
# 2       Sanjay_Dixit  IAS//DMET//BITS// Author, Krishna Gopeshvara, ...
# 3    Electroversenet  Accurately documenting Earth Changes as two wo...
# 4           sarawei3  女人的品质，决定着一个民族的未来🙏 基督徒 Graduate Certificate in ...
# ..               ...                                                ...
# 245          baalter  🇺🇸1A, 2A, USMC-Family, Conservative, Country, ...
# 246          SURSDIK  #TrumpTrain 🤣  🤣 #Draintheswamp 🤣 #Menacoverup...
# 247    ernie_plumley  God, Jesus, wife, family, and the Reborn Ameri...
# 248   John_KissMyBot  Donald J Trump is my President, Conservative, ...
# 249  Bamafanaticfan1  Married, #Women4Trump #MAGA #KAG2020 #NRAMembe...
#
#      verified  protected
# 0       False      False
# 1       False      False
# 2        True      False
# 3       False      False
# 4       False      False
# ..        ...        ...
# 245     False      False
# 246     False      False
# 247     False      False
# 248     False      False
# 249     False      False
#
# [250 rows x 8 columns]

# %%
ss_account_info = ss_account_info.merge(
    errors,
    left_on="u_id",
    right_on="user_id",
    how="left"
)

# Users with no 'status' variable in the `errors` object are still active!
ss_account_info["status"] = ss_account_info["status"].fillna("Active")

# %%
status_map = {
    'Active':'active',
    'User has been suspended':'suspended',
    'Could not find user with ids':'deleted'
}

ss_account_info.status = ss_account_info.status.map(status_map)

# %%
ss_account_info.head()
# Out:
#                   u_id  followers_count  following_count    tweet_count  \
# 0  1000141948269678592     56366.039735     56903.993377   96973.688742
# 1  1010682068131557376     13237.791667     13281.125000   65105.958333
# 2            101779040     85459.535714       199.464286  136737.321429
# 3  1018425398869282817     10784.678218        25.217822    7084.831683
# 4           1023362107     31915.972868       358.982558    7770.236434
#
#           username                                        description  \
# 0   209acesheepdog  🇺🇸🐶1A🗞~2A🔫CHRISTIAN⛪ CONSERVATIVE 💪\nMAR.30yrs...
# 1        DebHaslam  WWG1WGA👮‍♂️#MAGA🇺🇸❤️#TRUMP2020❤️🇺🇸 MY PAGE IS ...
# 2     Sanjay_Dixit  IAS//DMET//BITS// Author, Krishna Gopeshvara, ...
# 3  Electroversenet  Accurately documenting Earth Changes as two wo...
# 4         sarawei3  女人的品质，决定着一个民族的未来🙏 基督徒 Graduate Certificate in ...
#
#    verified  protected              user_id     status  \
# 0     False      False                  NaN     active
# 1     False      False  1010682068131557376  suspended
# 2      True      False                  NaN     active
# 3     False      False                  NaN     active
# 4     False      False           1023362107  suspended
#
#                                        twitter_error
# 0                                                NaN
# 1  https://api.twitter.com/2/problems/resource-no...
# 2                                                NaN
# 3                                                NaN
# 4  https://api.twitter.com/2/problems/resource-no...

# %%
ss_account_info.u_id.nunique()
# Out:
# 250

# %%
verified_map={
    True : "verified",
    False : "not verified"
}

ss_account_info.verified = ss_account_info.verified.map(verified_map)
ss_account_info
# Out:
#                     u_id  followers_count  following_count    tweet_count  \
# 0    1000141948269678592     56366.039735     56903.993377   96973.688742
# 1    1010682068131557376     13237.791667     13281.125000   65105.958333
# 2              101779040     85459.535714       199.464286  136737.321429
# 3    1018425398869282817     10784.678218        25.217822    7084.831683
# 4             1023362107     31915.972868       358.982558    7770.236434
# ..                   ...              ...              ...            ...
# 245            965259182     54812.569182     37505.399371  467860.204403
# 246   966716807452258304     34011.982222     34308.720000   42249.004444
# 247   969444209940889600     42852.500000     28818.166667  181323.166667
# 248            975217231    152649.985294     98170.279412  323830.455882
# 249   997312910748680192     42967.622807     43533.035088  175056.368421
#
#             username                                        description  \
# 0     209acesheepdog  🇺🇸🐶1A🗞~2A🔫CHRISTIAN⛪ CONSERVATIVE 💪\nMAR.30yrs...
# 1          DebHaslam  WWG1WGA👮‍♂️#MAGA🇺🇸❤️#TRUMP2020❤️🇺🇸 MY PAGE IS ...
# 2       Sanjay_Dixit  IAS//DMET//BITS// Author, Krishna Gopeshvara, ...
# 3    Electroversenet  Accurately documenting Earth Changes as two wo...
# 4           sarawei3  女人的品质，决定着一个民族的未来🙏 基督徒 Graduate Certificate in ...
# ..               ...                                                ...
# 245          baalter  🇺🇸1A, 2A, USMC-Family, Conservative, Country, ...
# 246          SURSDIK  #TrumpTrain 🤣  🤣 #Draintheswamp 🤣 #Menacoverup...
# 247    ernie_plumley  God, Jesus, wife, family, and the Reborn Ameri...
# 248   John_KissMyBot  Donald J Trump is my President, Conservative, ...
# 249  Bamafanaticfan1  Married, #Women4Trump #MAGA #KAG2020 #NRAMembe...
#
#          verified  protected              user_id     status  \
# 0    not verified      False                  NaN     active
# 1    not verified      False  1010682068131557376  suspended
# 2        verified      False                  NaN     active
# 3    not verified      False                  NaN     active
# 4    not verified      False           1023362107  suspended
# ..            ...        ...                  ...        ...
# 245  not verified      False            965259182  suspended
# 246  not verified      False   966716807452258304  suspended
# 247  not verified      False   969444209940889600  suspended
# 248  not verified      False            975217231  suspended
# 249  not verified      False   997312910748680192  suspended
#
#                                          twitter_error
# 0                                                  NaN
# 1    https://api.twitter.com/2/problems/resource-no...
# 2                                                  NaN
# 3                                                  NaN
# 4    https://api.twitter.com/2/problems/resource-no...
# ..                                                 ...
# 245  https://api.twitter.com/2/problems/resource-no...
# 246  https://api.twitter.com/2/problems/resource-no...
# 247  https://api.twitter.com/2/problems/resource-no...
# 248  https://api.twitter.com/2/problems/resource-no...
# 249  https://api.twitter.com/2/problems/resource-no...
#
# [250 rows x 11 columns]

# %% [markdown]
# ### Make figures

# %%
ss_account_info.head()
# Out:
#                   u_id  followers_count  following_count    tweet_count  \
# 0  1000141948269678592     56366.039735     56903.993377   96973.688742
# 1  1010682068131557376     13237.791667     13281.125000   65105.958333
# 2            101779040     85459.535714       199.464286  136737.321429
# 3  1018425398869282817     10784.678218        25.217822    7084.831683
# 4           1023362107     31915.972868       358.982558    7770.236434
#
#           username                                        description  \
# 0   209acesheepdog  🇺🇸🐶1A🗞~2A🔫CHRISTIAN⛪ CONSERVATIVE 💪\nMAR.30yrs...
# 1        DebHaslam  WWG1WGA👮‍♂️#MAGA🇺🇸❤️#TRUMP2020❤️🇺🇸 MY PAGE IS ...
# 2     Sanjay_Dixit  IAS//DMET//BITS// Author, Krishna Gopeshvara, ...
# 3  Electroversenet  Accurately documenting Earth Changes as two wo...
# 4         sarawei3  女人的品质，决定着一个民族的未来🙏 基督徒 Graduate Certificate in ...
#
#        verified  protected              user_id     status  \
# 0  not verified      False                  NaN     active
# 1  not verified      False  1010682068131557376  suspended
# 2      verified      False                  NaN     active
# 3  not verified      False                  NaN     active
# 4  not verified      False           1023362107  suspended
#
#                                        twitter_error
# 0                                                NaN
# 1  https://api.twitter.com/2/problems/resource-no...
# 2                                                NaN
# 3                                                NaN
# 4  https://api.twitter.com/2/problems/resource-no...

# %%
suspended_users = ss_account_info[ss_account_info['status']=='suspended'].reset_index(drop=True).copy()

suspended_users = suspended_users[['u_id', 'verified','status', 'followers_count']]

verified_split = (suspended_users['verified'].value_counts() / len(suspended_users)).reset_index()
verified_split
# Out:
#           index  verified
# 0  not verified  0.973214
# 1      verified  0.026786

# %%
SPLIT_VALUE = 150_000

suspended_users.loc[:, 'prominent'] = None

suspended_users.loc[suspended_users['followers_count'] > SPLIT_VALUE, "prominent"] = f"> {int(SPLIT_VALUE/1000)}K followers"
suspended_users.loc[suspended_users['followers_count'] < SPLIT_VALUE, "prominent"] = f"< {int(SPLIT_VALUE/1000)}K followers"

prominent_split = (suspended_users['prominent'].value_counts() / len(suspended_users)).reset_index()
prominent_split
# Out:
#               index  prominent
# 0  < 150K followers   0.901786
# 1  > 150K followers   0.098214

# %%
verified_bar = alt.Chart(verified_split).mark_bar(color='black').encode(
    x = alt.X(
        "verified:Q",
        axis=alt.Axis(
            orient='top',
            title = None,
            labels = False,
            ticks = False,
            values = np.arange(0,1.2,.2)
        ),
        scale = alt.Scale(domain = (0,1))
    ),
    y = alt.Y("index:N", title = None)
).properties(width=700)


verified_text = alt.Chart(verified_split).mark_text(
    dx=5,
    fontSize=14,
    align='left'
).encode(
    x = alt.X(
        "verified:Q",
        axis=alt.Axis(
            orient='top',
            title = ['Percent of suspended superspreaders'],
            format = "%"
        ),
        scale = alt.Scale(domain = (0,1))
    ),
    y = alt.Y("index:N", title = None),
    text = alt.Text(
        "verified:Q",
        format = ".1%",
        
    )
).properties(width=800)

verified_fig = alt.layer(verified_bar, verified_text)

# --------------------------------
prominent_bar = alt.Chart(prominent_split).mark_bar(color='dodgerblue').encode(
    x = alt.X(
        "prominent:Q",
        axis=alt.Axis(
            title = ['Percentage of suspended superspreaders'],
            format = "%",
            values = np.arange(0,1.2,.2)
        ),
        scale = alt.Scale(domain = (0,1))
    ),
    y = alt.Y("index:N", title = None)
).properties(width=700)

prominent_text = alt.Chart(prominent_split).mark_text(
    dx=5,
    fontSize=14,
    align='left'
).encode(
    x = alt.X(
        "prominent:Q",
        axis=alt.Axis(
            format = "%"
        ),
        scale = alt.Scale(domain = (0,1))
    ),
    y = alt.Y("index:N", title = None),
    text = alt.Text(
        "prominent:Q",
        format = ".1%",
        
    )
).properties(width=800)

prominent_fig = alt.layer(prominent_bar, prominent_text)

# --------------------------------
alt.vconcat(
    verified_fig,
    prominent_fig,
    spacing=5
).configure_axis(
    titleFontSize=15,
    labelFontSize=15
)
# Out:
# alt.VConcatChart(...)
